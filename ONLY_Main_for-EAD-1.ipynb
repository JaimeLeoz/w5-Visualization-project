# %% [markdown]
# # EAD base datos Airbnb

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# para pintar
import pylab as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt

# %%
# para que salga el grafico
# %matplotlib inline

# %% [markdown]
# ## Check what else needs cleaning

# %% [markdown]
# ---

# %%
arbnb_sql2 = pd.read_csv('../w4-ETL-Project/final_docs_to_sql/total_arbnb_final.csv')
arbnb_sql2.head()
# Out:
#    Unnamed: 0      id                          listing_url       scrape_id  \
# 0           0   11547   https://www.airbnb.com/rooms/11547  20220314155457
# 1           1   69998   https://www.airbnb.com/rooms/69998  20220314155457
# 2           2  100831  https://www.airbnb.com/rooms/100831  20220314155457
# 3           3  105891  https://www.airbnb.com/rooms/105891  20220314155457
# 4           4  106833  https://www.airbnb.com/rooms/106833  20220314155457
#
#   last_scraped                                         name  \
# 0   2022-03-14                         My home at the beach
# 1   2022-03-15            COZY HIDEAWAY  LOFT... MI AMOR...
# 2   2022-03-15            HOUSE IN MALLORCA - WiFi(ET-3045)
# 3   2022-03-14  VILLAGE HOUSE WITH POOL: IDEAL FOR FAMILIES
# 4   2022-03-14            Villa with a big pool in Mallorca
#
#                                          description  host_id  \
# 0  Sun, joy, relax, quality, beach & peace.<br />...    42942
# ...

# %%
arbnb_sql2.info('deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69014 entries, 0 to 69013
# Data columns (total 64 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   69014 non-null  int64
#  1   id                                           69014 non-null  int64
#  2   listing_url                                  69014 non-null  object
#  3   scrape_id                                    69014 non-null  int64
#  4   last_scraped                                 69014 non-null  object
#  5   name                                         69010 non-null  object
#  6   description                                  68114 non-null  object
#  7   host_id                                      69014 non-null  int64
#  8   host_url                                     69014 non-null  object
# ...

# %%
arbnb_sql2.drop(['name', 'description','host_verifications','Unnamed: 0'], axis=1)
# Out:
#              id                            listing_url       scrape_id  \
# 0         11547     https://www.airbnb.com/rooms/11547  20220314155457
# 1         69998     https://www.airbnb.com/rooms/69998  20220314155457
# 2        100831    https://www.airbnb.com/rooms/100831  20220314155457
# 3        105891    https://www.airbnb.com/rooms/105891  20220314155457
# 4        106833    https://www.airbnb.com/rooms/106833  20220314155457
# ...         ...                                    ...             ...
# 69009  53768559  https://www.airbnb.com/rooms/53768559  20211212213521
# 69010  53770992  https://www.airbnb.com/rooms/53770992  20211212213521
# 69011  53777865  https://www.airbnb.com/rooms/53777865  20211212213521
# 69012  53782321  https://www.airbnb.com/rooms/53782321  20211212213521
# 69013  53791212  https://www.airbnb.com/rooms/53791212  20211212213521
#
#       last_scraped    host_id                                     host_url  \
# ...

# %%
for c in arbnb_sql2.select_dtypes('integer').columns:
    arbnb_sql2[c] = pd.to_numeric(arbnb_sql2[c], downcast='integer')

# %%
for c in arbnb_sql2.select_dtypes('float').columns:
    arbnb_sql2[c] = pd.to_numeric(arbnb_sql2[c], downcast='float')

# %%
arbnb_sql2.info('deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69014 entries, 0 to 69013
# Data columns (total 64 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   69014 non-null  int16
#  1   id                                           69014 non-null  int64
#  2   listing_url                                  69014 non-null  object
#  3   scrape_id                                    69014 non-null  int64
#  4   last_scraped                                 69014 non-null  object
#  5   name                                         69010 non-null  object
#  6   description                                  68114 non-null  object
#  7   host_id                                      69014 non-null  int32
#  8   host_url                                     69014 non-null  object
# ...

# %%
arbnb_sql2 = arbnb_sql2.replace([np.inf, -np.inf], np.nan)
arbnb_sql2 = arbnb_sql2.fillna(0)

# %%
arbnb_sql2.shape
# Out:
# (69014, 64)

# %%
arbnb_sql2.dropna(subset=['price_sqm_amonth'], inplace=True)

# %%
arbnb_sql2['price_sqm_amonth']
# Out:
# 0         54.599998
# 1         52.200001
# 2         38.750000
# 3         38.823528
# 4        120.000000
#             ...
# 69009     99.500000
# 69010     15.000000
# 69011     74.470589
# 69012    117.000000
# 69013     51.000000
# Name: price_sqm_amonth, Length: 69014, dtype: float32

# %%
arbnb_sql2.dtypes['price']
# Out:
# dtype('float32')

# %%
arbnb_sql2.shape
# Out:
# (69014, 64)

# %%
nan_cols = arbnb_sql2.isnull().sum()
nan_cols
# Out:
# Unnamed: 0            0
# id                    0
# listing_url           0
# scrape_id             0
# last_scraped          0
#                      ..
# sq_meters             0
# price_monthly         0
# price_sqm_amonth      0
# last_scraped_month    0
# postal_codes          0
# Length: 64, dtype: int64

# %%
max (arbnb_sql2.price)
# Out:
# 90000.0

# %%
['price','review_scores_rating','number_of_reviews','price_monthly','price_sqm_amonth' ]
# Out:
# ['price',
#  'review_scores_rating',
#  'number_of_reviews',
#  'price_monthly',
#  'price_sqm_amonth']

# %%
stats = arbnb_sql2.describe().T

stats['IQR'] = stats['75%']-stats['25%']

stats
# Out:
#                                                count          mean  \
# Unnamed: 0                                   69014.0  9.027205e+03
# id                                           69014.0  2.372491e+16
# scrape_id                                    69014.0  2.021577e+13
# host_id                                      69014.0  1.329733e+08
# host_total_listings_count                    69014.0  1.262637e+02
# latitude                                     69014.0  3.966357e+01
# longitude                                    69014.0  2.998443e+00
# accommodates                                 69014.0  5.631524e+00
# bedrooms                                     69014.0  2.792607e+00
# beds                                         69014.0  4.180210e+00
# price                                        69014.0  2.460868e+02
# minimum_nights                               69014.0  4.369012e+00
# maximum_nights                               69014.0  7.884520e+02
# ...

# %%
arbnb_sql2[['price_sqm_amonth']].boxplot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
arbnb_sql2.property_type.value_counts()
# Out:
# Entire villa                          19994
# Entire rental unit                    13565
# Entire residential home               13129
# Entire home                            4628
# Entire cottage                         3493
#                                       ...
# Bus                                       1
# Private room in minsu                     1
# Private room in island                    1
# Shared room in condominium (condo)        1
# Shared room in guesthouse                 1
# Name: property_type, Length: 93, dtype: int64

# %%
arbnb_sql2.license.value_counts()
# Out:
# 0             26428
# A/1748          206
# A-PM-2176        60
# AG/049           56
# 2.20€            53
#               ...
# VT457             1
# ET 3422 ME        1
# ET3747            1
# VT / 1650         1
# ETV/7706          1
# Name: license, Length: 10338, dtype: int64

# %%
#quizas a esta podamos hacerle una mediana ( hay 22205 reviews vacias, realmente no tiene sentido rellenarlas si quiero usarlas)

arbnb_sql2.review_scores_rating	.value_counts()
# Out:
# 0.00    22408
# 5.00    14918
# 4.00     2690
# 4.50     2315
# 4.67     1886
#         ...
# 3.77        1
# 3.65        1
# 2.75        1
# 3.81        1
# 3.11        1
# Name: review_scores_rating, Length: 169, dtype: int64

# %%
arbnb_sql2.review_scores_rating.dtype
# Out:
# dtype('float32')

# %%
arbnb_sql2.bathrooms_text.dtypes
# Out:
# dtype('O')

# %%
arbnb_sql2.bathrooms_text.unique()
# Out:
# array(['1 bath', '3 baths', '2 baths', '1 private bath', '0 baths',
#        '1.5 baths', '2 shared baths', '4.5 baths', '2.5 baths', '4 baths',
#        'Shared half-bath', '1.5 shared baths', '3.5 baths', '5.5 baths',
#        '1 shared bath', '6 baths', 0, '7 baths', '5 baths', '8.5 baths',
#        '6.5 baths', '7.5 baths', '9.5 baths', '4 shared baths', '8 baths',
#        'Half-bath', '0 shared baths', '11 baths', '3.5 shared baths',
#        '2.5 shared baths', '9 baths', '11.5 baths', '3 shared baths',
#        '10 baths', 'Private half-bath', '10.5 baths'], dtype=object)

# %%
arbnb_sql2['bathrooms_text'] = arbnb_sql2['bathrooms_text'].astype(str)

# %%
arbnb_sql2.bathrooms_text.dtypes
# Out:
# dtype('O')

# %%
# Limpiando la columna de baños, asi puedo usarla mas adelante. Crearé un par de columnas, 1 del tipo y la otra  del número.

bathroom_types=[]

for i in arbnb_sql2.bathrooms_text:
    if i.find("bath") ==0:
        bathroom_types.append("baths")
    elif i.find("baths") ==0:
        bathroom_types.append("baths")
    elif i.find("private") ==0:
        bathroom_types.append("private bath")
    elif i.find("shared") ==0:
        bathroom_types.append("shared bath")
    elif i.find("half-") ==0:
        bathroom_types.append("half bath")
    elif i.find("Shared ") ==0:
        bathroom_types.append("shared bath")
 
    else:
        bathroom_types.append(i)

arbnb_sql2["bathroom_types"] = bathroom_types

# %%
# Aquí le decimos la separación por espacio para poder crear las columnas por dos

new = arbnb_sql2["bathroom_types"].str.split(" ", n = 1, expand = True)

# %%
# Damos nombre a la primer columna creada
arbnb_sql2["number_bathroom"]= new[0]

# %%
# Damos nombre a la segunda columna creada

arbnb_sql2["type_bathroom_fin"]= new[1]

# %%
arbnb_sql2.head()
# Out:
#    Unnamed: 0      id                          listing_url       scrape_id  \
# 0           0   11547   https://www.airbnb.com/rooms/11547  20220314155457
# 1           1   69998   https://www.airbnb.com/rooms/69998  20220314155457
# 2           2  100831  https://www.airbnb.com/rooms/100831  20220314155457
# 3           3  105891  https://www.airbnb.com/rooms/105891  20220314155457
# 4           4  106833  https://www.airbnb.com/rooms/106833  20220314155457
#
#   last_scraped                                         name  \
# 0   2022-03-14                         My home at the beach
# 1   2022-03-15            COZY HIDEAWAY  LOFT... MI AMOR...
# 2   2022-03-15            HOUSE IN MALLORCA - WiFi(ET-3045)
# 3   2022-03-14  VILLAGE HOUSE WITH POOL: IDEAL FOR FAMILIES
# 4   2022-03-14            Villa with a big pool in Mallorca
#
#                                          description  host_id  \
# 0  Sun, joy, relax, quality, beach & peace.<br />...    42942
# ...

# %%
arbnb_sql2.type_bathroom_fin.value_counts()
# Out:
# baths           47027
# bath            16937
# private bath     2331
# shared bath      1866
# shared baths      715
# half-bath           4
# Name: type_bathroom_fin, dtype: int64

# %%
#tiramos la columna que creamos mas limpia.

arbnb_sql2.drop(columns =["bathroom_types"], inplace = True)

# %%
arbnb_sql2.head()
# Out:
#    Unnamed: 0      id                          listing_url       scrape_id  \
# 0           0   11547   https://www.airbnb.com/rooms/11547  20220314155457
# 1           1   69998   https://www.airbnb.com/rooms/69998  20220314155457
# 2           2  100831  https://www.airbnb.com/rooms/100831  20220314155457
# 3           3  105891  https://www.airbnb.com/rooms/105891  20220314155457
# 4           4  106833  https://www.airbnb.com/rooms/106833  20220314155457
#
#   last_scraped                                         name  \
# 0   2022-03-14                         My home at the beach
# 1   2022-03-15            COZY HIDEAWAY  LOFT... MI AMOR...
# 2   2022-03-15            HOUSE IN MALLORCA - WiFi(ET-3045)
# 3   2022-03-14  VILLAGE HOUSE WITH POOL: IDEAL FOR FAMILIES
# 4   2022-03-14            Villa with a big pool in Mallorca
#
#                                          description  host_id  \
# 0  Sun, joy, relax, quality, beach & peace.<br />...    42942
# ...

# %%
arbnb_sql2.drop(['name', 'description','host_verifications','Unnamed: 0'], inplace=True, axis=1)

# %% [markdown]
# ---

# %% [markdown]
# ## Reviwing outliers and filtering the DB

# %% [markdown]
# ----

# %%
# empezamos por los precios, sabemos que hay un precio que está distorsionando todos los valores. A 90K la noche

arbnb_sql2.price.describe()
# Out:
# count    69014.000000
# mean       246.086761
# std        645.035339
# min          0.000000
# 25%        104.000000
# 50%        168.000000
# 75%        268.000000
# max      90000.000000
# Name: price, dtype: float64

# %%
# the crazy outlier

arbnb_sql2[arbnb_sql2.price == max(arbnb_sql2.price)]
# Out:
#              id                            listing_url       scrape_id  \
# 30278  50360402  https://www.airbnb.com/rooms/50360402  20220610041431
#
#       last_scraped    host_id                                     host_url  \
# 30278   2022-06-10  367306238  https://www.airbnb.com/users/show/367306238
#
#       host_name  host_since                          host_location  \
# 30278   Enrique  2020-09-13  Cala Figuera, Balearic Islands, Spain
#
#       host_acceptance_rate host_is_superhost  host_total_listings_count  \
# 30278                 100%                 f                        1.0
#
#       host_identity_verified neighbourhood neighbourhood_cleansed   latitude  \
# 30278                      t             0               Santanyi  39.328548
#
#        longitude       property_type        room_type  accommodates  \
# 30278    3.17067  Entire rental unit  Entire home/apt             2
#
#       bathrooms_text  bedrooms  beds    price  minimum_nights  maximum_nights  \
# ...

# %%
plt.figsize=(10,30)

arbnb_sql2.price.hist(bins=50)

plt.xlabel('Price')
plt.ylabel('Count');

# %%
arbnb_sql2.boxplot(column=['price'])
# Out:
# <AxesSubplot:>

# %%
(arbnb_sql2[arbnb_sql2.price==min(arbnb_sql2.price)])
# Out:
#              id                            listing_url       scrape_id  \
# 10470  42384657  https://www.airbnb.com/rooms/42384657  20220314155457
# 10678  43078001  https://www.airbnb.com/rooms/43078001  20220314155457
# 11912  46634680  https://www.airbnb.com/rooms/46634680  20220314155457
# 27038  42384657  https://www.airbnb.com/rooms/42384657  20220610041431
# 27335  43078001  https://www.airbnb.com/rooms/43078001  20220610041431
# 46152  42384657  https://www.airbnb.com/rooms/42384657  20210914193210
# 46414  43078001  https://www.airbnb.com/rooms/43078001  20210914193210
# 48132  46634680  https://www.airbnb.com/rooms/46634680  20210914193210
# 63013  42384657  https://www.airbnb.com/rooms/42384657  20211212213521
# 63241  43078001  https://www.airbnb.com/rooms/43078001  20211212213521
# 64768  46634680  https://www.airbnb.com/rooms/46634680  20211212213521
#
#       last_scraped    host_id                                     host_url  \
# ...

# %%
arbnb_sql2[arbnb_sql2.price == 0].shape[0]
# Out:
# 11

# %%
arbnb_sql2.price.describe()
# Out:
# count    69014.000000
# mean       246.086761
# std        645.035339
# min          0.000000
# 25%        104.000000
# 50%        168.000000
# 75%        268.000000
# max      90000.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,8))
arbnb_sql2[arbnb_sql2.price<1000].boxplot(column=['price']);

# %%
plt.figure(figsize=(10, 6))

arbnb_sql2[arbnb_sql2.price< 1000].price.hist(bins=100);

# %%
data = arbnb_sql2[arbnb_sql2.price< 450].price

data.hist(bins=100)

plt.xlabel('Price')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
data.shape
# Out:
# (62823,)

# %%
data.describe()
# Out:
# count    62823.000000
# mean       173.274582
# std         98.597115
# min          0.000000
# 25%        100.000000
# 50%        155.000000
# 75%        234.000000
# max        449.000000
# Name: price, dtype: float64

# %%
arbnb_sql2.shape
# Out:
# (69014, 62)

# %%
#filtramos con varibale nueva para quitar los airbnb con ceros y aquellos mayores de 450 euros 

arbnb_prices = arbnb_sql2[(arbnb_sql2['price'] > 0) & (arbnb_sql2['price'] < 450)]
arbnb_prices.shape
# Out:
# (62812, 62)

# %%
arbnb_prices.boxplot(column=['price_sqm_amonth'])
# Out:
# <AxesSubplot:>

# %%
arbnb_prices.describe().T
# Out:
#                                                count          mean  \
# id                                           62812.0  2.308260e+16
# scrape_id                                    62812.0  2.021574e+13
# host_id                                      62812.0  1.335429e+08
# host_total_listings_count                    62812.0  1.293121e+02
# latitude                                     62812.0  3.966334e+01
# longitude                                    62812.0  3.003634e+00
# accommodates                                 62812.0  5.339091e+00
# bedrooms                                     62812.0  2.644717e+00
# beds                                         62812.0  3.990463e+00
# price                                        62812.0  1.733049e+02
# minimum_nights                               62812.0  4.335812e+00
# maximum_nights                               62812.0  7.901162e+02
# minimum_minimum_nights                       62812.0  4.211409e+00
# ...

# %%
arbnb_prices2 = arbnb_sql2[(arbnb_sql2.price<450)]
arbnb_prices2.shape
# Out:
# (62823, 62)

# %%
#filtramos aquellos que son mayores de 450 por si queremos hacer otra tabla y jugar con ella para TOP Lux Vacation

arbnb_top_places2 = arbnb_sql2[(arbnb_sql2.price >= 450)]
arbnb_top_places2.shape
# Out:
# (6191, 62)

# %%
import pandas as pd
import openpyxl

# %%
# arbnb_top_places2.to_csv('./final_docs_to_sql/arbnbtoplacesfinal.csv', index= False)

# %%
# arbnb_top_places2.to_excel('./final_docs_to_sql/arbnbtoplacesfinal.xlsx', index= False)

# %%
# arbnb_prices2.to_excel('./final_docs_to_sql/arbnb_prices_final.xlsx', index= False)

# %%
#filtramos por todos aquellos precions menores

# %%
realrent= pd.read_csv(r'./final_docs_to_sql/scraped_rent_municipios_final2.csv')
realrent.head()
# Out:
#               municipios precio_medio_sqm_apartm precio_medio_sqm_casa  \
# 0      Palma de Mallorca                  3238 €                2930 €
# 1                 Calvia                  4531 €                5357 €
# 2                Manacor                  1800 €                1927 €
# 3  Santa Eularia des Riu                  5167 €                6825 €
# 4              Llucmajor                  2700 €                2930 €
#
#    precio_medio_sqm_alqu  poblacion  price_sqm_amonth_alqu  postal_codes
# 0                    141    409.652              11.750000          7001
# 1                    216     49.327              18.000000          7184
# 2                    109     42.634               9.083333          7500
# 3                    230     41.783              19.166667          7840
# 4                    137     36.364              11.416667          7620

# %%
realrent.to_excel(r'./final_docs_to_sql/realrent_dashboard.xlsx', index=False)
